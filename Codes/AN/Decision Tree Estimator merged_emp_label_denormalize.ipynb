# %% [markdown]
# ### Decision tree Estimator on merged_emp data
#
# - This Python notebook demonstrates creating an ML Pipeline to preprocess a dataset, train a Machine Learning model, and make predictions.
#
# - Data: The dataset contains    merged_emp data
#
# - Goal: We want to learn to predict  deaths  from features such as patient data (comprising of Adult_smoking_percentage,	Adult_obesity_percentage and Excessive_drinking_percentage), various healthcare data like hospitals, physician, nurses, surgean specialities, etc., socio econonmic factors like life rank, quality of life, social-ecomonica factors rank, physical environment rank, etc. and other features like popluation, etc.
#
# - Approach: We will use Spark ML Pipelines, which help users piece together parts of a workflow such as feature processing and model training. We will also demonstrate model selection (a.k.a. hyperparameter tuning) using Cross Validation in order to fine-tune and improve our ML model.

# %%
# %sh 
pip install mleap
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Requirement already satisfied: mleap in /databricks/conda/envs/databricks-ml/lib/python3.7/site-packages (0.8.1)
# Requirement already satisfied: argparse&gt;=1.1 in /databricks/conda/envs/databricks-ml/lib/python3.7/site-packages (from mleap) (1.4.0)
# Requirement already satisfied: nose-exclude&gt;=0.5.0 in /databricks/conda/envs/databricks-ml/lib/python3.7/site-packages (from mleap) (0.5.0)
# Requirement already satisfied: scipy&gt;=0.13.0b1 in /databricks/conda/envs/databricks-ml/lib/python3.7/site-packages (from mleap) (1.2.1)
# Requirement already satisfied: numpy&gt;=1.8.2 in /databricks/conda/envs/databricks-ml/lib/python3.7/site-packages (from mleap) (1.18.5)
# Requirement already satisfied: six&gt;=1.10.0 in /databricks/conda/envs/databricks-ml/lib/python3.7/site-packages (from mleap) (1.12.0)
# Requirement already satisfied: pandas&gt;=0.18.1 in /databricks/conda/envs/databricks-ml/lib/python3.7/site-packages (from mleap) (1.0.4)
# Requirement already satisfied: scikit-learn&gt;=0.18.dev0 in /databricks/conda/envs/databricks-ml/lib/python3.7/site-packages (from mleap) (0.20.3)
# Requirement already satisfied: nose in /databricks/conda/envs/databricks-ml/lib/python3.7/site-packages (from nose-exclude&gt;=0.5.0-&gt;mleap) (1.3.7)
# Requirement already satisfied: python-dateutil&gt;=2.6.1 in /databricks/conda/envs/databricks-ml/lib/python3.7/site-packages (from pandas&gt;=0.18.1-&gt;mleap) (2.8.0)
# Requirement already satisfied: pytz&gt;=2017.2 in /databricks/conda/envs/databricks-ml/lib/python3.7/site-packages (from pandas&gt;=0.18.1-&gt;mleap) (2018.9)
# </div>

# %%
from pyspark.sql.functions import log
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# read data from the output of exploratory data analysis which is in parquet file format
df = spark.read.parquet('/databricks/driver/spark_merged_emp_modeling1.parquet')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>county</th><th>cases</th><th>deaths</th><th>POP_ESTIMATE_2018</th><th>All_Specialties_AAMC</th><th>Total_nurse_practitioners_2019</th><th>Total_physician_assistants_2019</th><th>Total_Hospitals_2019</th><th>Total_Primary_Care_Physicians_2019</th><th>Surgery_specialists_2019</th><th>Emergency_Medicine_specialists_2019</th><th>Total_Specialist_Physicians_2019</th><th>ICU_Beds</th><th>pop_fraction</th><th>Length_of_Life_rank</th><th>Quality_of_Life_rank</th><th>Health_Behaviors_rank</th><th>Clinical_Care_rank</th><th>Social_Economic_Factors_rank</th><th>Physical_Environment_rank</th><th>Adult_smoking_percentage</th><th>Adult_obesity_percentage</th><th>Excessive_drinking_percentage</th><th>Population_per_sq_mile</th><th>House_per_sq_mile</th><th>Unemployed_2019</th><th>Unemployment_rate_2019</th><th>Median_Household_Income_2018</th><th>Med_HH_Income_Percent_of_State_Total_2018</th></tr></thead><tbody><tr><td>Lee</td><td>7.117022517792556</td><td>0.5833625014584063</td><td>17142.0</td><td>2.2945925621281065</td><td>0.4171807667133357</td><td>0.20632844143040488</td><td>0.013571651557577879</td><td>1.257836399486641</td><td>0.1581392439621981</td><td>0.14319075819

# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#sort columns according to column name
df = df.select(sorted(df.columns))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: 2920</div>

# %%
df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[8]: [(&#39;Adult_obesity_percentage&#39;, &#39;double&#39;),
#  (&#39;Adult_smoking_percentage&#39;, &#39;double&#39;),
#  (&#39;All_Specialties_AAMC&#39;, &#39;double&#39;),
#  (&#39;Clinical_Care_rank&#39;, &#39;double&#39;),
#  (&#39;Emergency_Medicine_specialists_2019&#39;, &#39;double&#39;),
#  (&#39;Excessive_drinking_percentage&#39;, &#39;double&#39;),
#  (&#39;Health_Behaviors_rank&#39;, &#39;double&#39;),
#  (&#39;House_per_sq_mile&#39;, &#39;double&#39;),
#  (&#39;ICU_Beds&#39;, &#39;double&#39;),
#  (&#39;Length_of_Life_rank&#39;, &#39;double&#39;),
#  (&#39;Med_HH_Income_Percent_of_State_Total_2018&#39;, &#39;double&#39;),
#  (&#39;Median_Household_Income_2018&#39;, &#39;double&#39;),
#  (&#39;POP_ESTIMATE_2018&#39;, &#39;double&#39;),
#  (&#39;Physical_Environment_rank&#39;, &#39;double&#39;),
#  (&#39;Population_per_sq_mile&#39;, &#39;double&#39;),
#  (&#39;Quality_of_Life_rank&#39;, &#39;double&#39;),
#  (&#39;Social_Economic_Factors_rank&#39;, &#39;double&#39;),
#  (&#39;Surgery_specialists_2019&#39;, &#39;double&#39;),
#  (&#39;Total_Hospitals_2019&#39;, &#39;double&#39;),
#  (&#39;Total_Primary_Care_Physicians_2019&#39;, &#39;double&#39;),
#  (&#39;Total_Specialist_Physicians_2019&#39;, &#39;double&#39;),
#  (&#39;Total_nurse_practitioners_2019&#39;, &#39;double&#39;),
#  (&#39;Total_physician_assistants_2019&#39;, &#39;double&#39;),
#  (&#39;Unemployed_2019&#39;, &#39;double&#39;),
#  (&#39;Unemployment_rate_2019&#39;, &#39;double&#39;),
#  (&#39;cases&#39;, &#39;double&#39;),
#  (&#39;county&#39;, &#39;string&#39;),
#  (&#39;pop_fraction&#39;, &#39;double&#39;),
#  (&#39;zlabel&#39;, &#39;double&#39;)]</div>

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Adult_obesity_percentage</th><th>Adult_smoking_percentage</th><th>All_Specialties_AAMC</th><th>Clinical_Care_rank</th><th>Emergency_Medicine_specialists_2019</th><th>Excessive_drinking_percentage</th><th>Health_Behaviors_rank</th><th>House_per_sq_mile</th><th>ICU_Beds</th><th>Length_of_Life_rank</th><th>Med_HH_Income_Percent_of_State_Total_2018</th><th>Median_Household_Income_2018</th><th>POP_ESTIMATE_2018</th><th>Physical_Environment_rank</th><th>Population_per_sq_mile</th><th>Quality_of_Life_rank</th><th>Social_Economic_Factors_rank</th><th>Surgery_specialists_2019</th><th>Total_Hospitals_2019</th><th>Total_Primary_Care_Physicians_2019</th><th>Total_Specialist_Physicians_2019</th><th>Total_nurse_practitioners_2019</th><th>Total_physician_assistants_2019</th><th>Unemployed_2019</th><th>Unemployment_rate_2019</th><th>cases</th><th>county</th><th>pop_fraction</th><th>zlabel</th></tr></thead><tbody><tr><td>40.0</td><td>21.0</td><td>2.2945925621281065</td><td>41.0</td><td>0.14319075819624313</td><td>13.
td><td>45.0</td><td>0.15813924395787562</td><td>0.013571651526630805</td><td>1.2578363993484354</td><td>1.2690477638457458</td><td>0.41718076672475185</td><td>0.20632844143495718</td><td>444.0</td><td>4.8</td><td>2.272899462080461</td><td>Marlboro</td><td>0.002596119</td><td>0.0</td></tr><tr><td>34.0</td><td>17.0</td><td>2.2945925621679066</td><td>4.0</td><td>0.14319075823591926</td><td>14.0</td><td>9.0</td><td>15.2</td><td>0.0</td><td>46.0</td><td>85.19323533</td><td>44683.0</td><td>9410.0</td><td>13.0</td><td>28.5</td><td>25.0</td><td>34.0</td><td>0.15813924399574922</td><td>0.013571651540913922</td><td>1.2578363995749204</td><td>1.2690477640807651</td><td>0.41718076673751325</td><td>0.206328441445271</td><td>104.0</td><td>3.1</td><td>0.7438894792773645</td><td>McCormick</td><td>9.25429E-4</td><td>0.10626992561105207</td></tr><tr><td>36.0</td><td>18.0</td><td>2.294592562305296</td><td>21.0</td><td>0.14319075822949118</td><td>16.0</td><td>23.0</td><td>28.4</td><td>0.181723779854621</td><td>10.0</td><td>91.57276592</td><td>48 ...

# %%
df.where( df['label'].isNull() ).count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[12]: 0</div>

# %%
df.where( df['pop_fraction'].isNull() ).count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[13]: 30</div>

# %%
#define a function to identify the count of nulls in the columns
def count_nulls(df):
    null_counts = []          #make an empty list to hold our results
    for col in df.dtypes:     #iterate through the column data types we saw above, e.g. ('C0', 'bigint')
        cname = col[0]        #splits out the column name, e.g. 'C0'    
        ctype = col[1]        #splits out the column type, e.g. 'bigint'
        if ctype != 'string': #skip processing string columns for efficiency (can't have nulls)
            nulls = df.where( df[cname].isNull() ).count()
            result = tuple([cname, nulls])  #new tuple, (column name, null count)
            null_counts.append(result)      #put the new tuple in our result list
    return null_counts

null_counts = count_nulls(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
null_counts
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[15]: [(&#39;Adult_obesity_percentage&#39;, 0),
#  (&#39;Adult_smoking_percentage&#39;, 0),
#  (&#39;All_Specialties_AAMC&#39;, 0),
#  (&#39;Clinical_Care_rank&#39;, 0),
#  (&#39;Emergency_Medicine_specialists_2019&#39;, 0),
#  (&#39;Excessive_drinking_percentage&#39;, 0),
#  (&#39;Health_Behaviors_rank&#39;, 0),
#  (&#39;House_per_sq_mile&#39;, 0),
#  (&#39;ICU_Beds&#39;, 0),
#  (&#39;Length_of_Life_rank&#39;, 0),
#  (&#39;Med_HH_Income_Percent_of_State_Total_2018&#39;, 0),
#  (&#39;Median_Household_Income_2018&#39;, 0),
#  (&#39;POP_ESTIMATE_2018&#39;, 30),
#  (&#39;Physical_Environment_rank&#39;, 0),
#  (&#39;Population_per_sq_mile&#39;, 0),
#  (&#39;Quality_of_Life_rank&#39;, 0),
#  (&#39;Social_Economic_Factors_rank&#39;, 0),
#  (&#39;Surgery_specialists_2019&#39;, 0),
#  (&#39;Total_Hospitals_2019&#39;, 0),
#  (&#39;Total_Primary_Care_Physicians_2019&#39;, 0),
#  (&#39;Total_Specialist_Physicians_2019&#39;, 0),
#  (&#39;Total_nurse_practitioners_2019&#39;, 0),
#  (&#39;Total_physician_assistants_2019&#39;, 0),
#  (&#39;Unemployed_2019&#39;, 0),
#  (&#39;Unemployment_rate_2019&#39;, 0),
#  (&#39;cases&#39;, 0),
#  (&#39;pop_fraction&#39;, 30),
#  (&#39;label&#39;, 0)]</div>

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>
td><td>15.0</td><td>40.0</td><td>25.2</td><td>0.0</td><td>43.0</td><td>63.93639536</td><td>33534.0</td><td>26398.0</td><td>44.0</td><td>60.3</td><td>39.0</td><td>45.0</td><td>0.15813924395787562</td><td>0.013571651526630805</td><td>1.2578363993484354</td><td>1.2690477638457458</td><td>0.41718076672475185</td><td>0.20632844143495718</td><td>444.0</td><td>4.8</td><td>2.272899462080461</td><td>Marlboro</td><td>0.002596119</td><td>0.0</td></tr><tr><td>34.0</td><td>17.0</td><td>2.2945925621679066</td><td>4.0</td><td>0.14319075823591926</td><td>14.0</td><td>9.0</td><td>15.2</td><td>0.0</td><td>46.0</td><td>85.19323533</td><td>44683.0</td><td>9410.0</td><td>13.0</td><td>28.5</td><td>25.0</td><td>34.0</td><td>0.15813924399574922</td><td>0.013571651540913922</td><td>1.2578363995749204</td><td>1.2690477640807651</td><td>0.41718076673751325</td><td>0.206328441445271</td><td>104.0</td><td>3.1</td><td>0.7438894792773645</td><td>McCormick</td><td>9.25429E-4</td><td>0.10626992561105207</td></tr><tr><td>36.0</td><td>18.0</td><td>2.294592562305296</td><td>21.0</td><td>0.14319075822949118</td><td>16.0</td><td>23.0</td><td>28.4</td><td>0.181723779854621</td><td>10.0</td><td>91.57276592</td><td>48 ...

# %%
df = df.drop("pop_fraction")
df_temp=df_temp.drop("pop_fraction")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_described = df.describe()
df_described.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+------------------------+------------------------+--------------------+------------------+-----------------------------------+-----------------------------+---------------------+------------------+------------------+-------------------+-----------------------------------------+----------------------------+------------------+-------------------------+----------------------+--------------------+----------------------------+------------------------+--------------------+----------------------------------+--------------------------------+------------------------------+-------------------------------+------------------+----------------------+--------------------+---------+-------------------+
# summary|Adult_obesity_percentage|Adult_smoking_percentage|All_Specialties_AAMC|Clinical_Care_rank|Emergency_Medicine_specialists_2019|Excessive_drinking_percentage|Health_Behaviors_rank| House_per_sq_mile|          ICU_Beds|Length_of_Life_rank|Med_HH_Income_Percent_of_State_Total_2018|Median_Household_Income_2018| POP_ESTIMATE_2018|Physical_Environment_rank|Population_per_sq_mile|Quality_of_Life_rank|Social_Economic_Factors_rank|Surgery_specialists_2019|Total_Hospitals_2019|Total_Primary_Care_Physicians_2019|Total_Specialist_Physicians_2019|Total_nurse_practitioners_2019|Total_physician_assistants_2019|   Unemployed_2019|Unemployment_rate_2019|               cases|   county|              label|
# +-------+------------------------+------------------------+--------------------+------------------+-----------------------------------+-----------------------------+---------------------+------------------+------------------+-------------------+-----------------------------------------+----------------------------+------------------+-------------------------+----------------------+--------------------+----------------------------+------------------------+--------------------+----------------------------------+--------------------------------+------------------------------+-------------------------------+------------------+----------------------+--------------------+---------+-------------------+
#   count|                    2920|                    2920|                2920|              2920|                               2920|                         2920|                 2920|              2920|              2920|               2920|                                     2920|                        2920|              2890|                     2920|                  2920|                2920|                        2920|                    2920|                2920|                              2920|                            2920|                          2920|                           2920|              2920|                  2920|                2920|     2920|               2920|
#    mean|      33.068166089965395|      17.554671280276814|  2.5584090761475906| 46.80800000000001|                0.15517237341472012|            17.51280276816609|    48.40382608695652| 97.04292142609899|0.1416556103918164|  46.90747826086957|                        90.08975735053288|           53112.23287197231|109859.56712802769|        49.47965217391304|     223.1832467982001|  47.572173913043486|           47.64799999999999|     0.15678187709488492|0.022360032084671223|                1.3832442105763176|              1.4630687143103664|            0.5153777259287423|            0.26318240467730636|2007.0051903114188|     4.006297577854671|  2.3734327601716774|     null|0.09867339905928069|
#  stddev|       5.429846945234563|      3.5345823419759763|  0.4277294587437189| 40.29271118768756|                0.05169390510679405|            3.175252580101332|   41.677558663716596|346.20795974896356|0.5429733388072986|   41.3505116416244|                        20.25639569033717|          14034.702653941114| 338843.6418601639|        42.14004433599951|     776.2830201250127|   41.14424435336909|           41.19115348867994|     0.03422826532246513|0.012286295306214305|               0.26311556941990233|              0.3433993192893988|           0.11954393548085461|            0.10668379320578586|6631.4655606166825|    1.4121948910978879|   4.992203702745789|     null| 0.2214383392342358|
#     min|                    12.0|                     6.0|  1.9132571908978813|               1.0|                0.06574212065070041|                          8.0|                  1.0|               0.0|               0.0|                1.0|                              43.86023433|                     25385.0|             655.0|                      1.0|                   0.0|                 1.0|                         1.0|     0.08493861579414375|0.007237603276393...|                0.9217835054678007|              0.7952306679389312|           0.27715601667113704|           0.035827532226287644|               9.0|                   1.4|0.015645534764378247|Abbeville|                0.0|
#     max|                    58.0|                    41.0|   8.470293470756134|             244.0|                 0.5324184467332427|                         29.0|                244.0|            8041.8|27.452256944444443|              244.0|                              263.5734627|                    140382.0|       1.0105518E7|                    244.0|               17179.2|               242.0|                       244.0|      0.6050209621968667| 0.06460863624039766|                  4.52128606102882|               5.936323323202198|            0.9075434334231974|            0.46919198642294396|          227288.0|                  18.3|  125.40864511442064|    varro| 3.0733206497877945|
# +-------+------------------------+------------------------+--------------------+------------------+-----------------------------------+-----------------------------+---------------------+------------------+------------------+-------------------+-----------------------------------------+----------------------------+------------------+-------------------------+----------------------+--------------------+----------------------------+------------------------+--------------------+----------------------------------+--------------------------------+------------------------------+-------------------------------+------------------+----------------------+--------------------+---------+-------------------+
#
# </div>

# %%
from pyspark.sql.functions import skewness, kurtosis
from pyspark.sql.functions import var_pop, var_samp, stddev, stddev_pop, sumDistinct, ntile
df.select(skewness('label')).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+
#   skewness(label)|
# +-----------------+
# 5.052373505505389|
# +-----------------+
#
# </div>

# %%
from pyspark.sql import Row

columns = df_described.columns  #list of column names
funcs   = [skewness, kurtosis]  #list of functions we want to include (imported earlier)
fnames  = ['skew', 'kurtosis']  #a list of strings describing the functions in the same order

def new_item(func, column):
    """
    This function takes in an aggregation function and a column name, then applies the aggregation to the
    column, collects it and returns a value.  The value is in string format despite being a number, 
    because that matches the output of describe.
    """
    return str(df.select(func(column)).collect()[0][0])

new_data = []
for func, fname in zip(funcs, fnames):
    row_dict = {'summary':fname}  #each row object begins with an entry for "summary"
    for column in columns[1:]:
        row_dict[column] = new_item(func, column)
    new_data.append(Row(**row_dict))  #using ** tells Python to unpack the entries of the dictionary
    
print(new_data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[
#  Row(summary=&#39;max&#39;, Adult_obesity_percentage=&#39;58.0&#39;, Adult_smoking_percentage=&#39;41.0&#39;, All_Specialties_AAMC=&#39;8.470293470756134&#39;, Clinical_Care_rank=&#39;244.0&#39;, Emergency_Medicine_specialists_2019=&#39;0.5324184467332427&#39;, Excessive_drinking_percentage=&#39;29.0&#39;, Health_Behaviors_rank=&#39;244.0&#39;, House_per_sq_mile=&#39;8041.8&#39;, ICU_Beds=&#39;27.452256944444443&#39;, Length_of_Life_rank=&#39;244.0&#39;, Med_HH_Income_Percent_of_State_Total_2018=&#39;263.5734627&#39;, Median_Household_Income_2018=&#39;140382.0&#39;, POP_ESTIMATE_2018=&#39;1.0105518E7&#39;, Physical_Environment_rank=&#39;244.0&#39;, Population_per_sq_mile=&#39;17179.2&#39;, Quality_of_Life_rank=&#39;242.0&#39;, Social_Economic_Factors_rank=&#39;244.0&#39;, Surgery_specialists_2019=&#39;0.6050209621968667&#39;, Total_Hospitals_2019=&#39;0.06460863624039766&#39;, Total_Primary_Care_Physicians_2019=&#39;4.52128606102882&#39;, Total_Specialist_Physicians_2019=&#39;5.936323323202198&#39;, Total_nurse_practitioners_2019=&#39;0.9075434334231974&#39;, Total_physician_assistants_2019=&#39;0.46919198642294396&#39;, Unemployed_2019=&#39;227288.0&#39;, Unemployment_rate_2019=&#39;18.3&#39;, cases=&#39;125.40864511442064&#39;, county=&#39;varro&#39;, label=&#39;3.0733206497877945&#39;)]</div>

# %%
new_describe = sc.parallelize(new_data).toDF()           #turns the results from our loop into a dataframe
new_describe = new_describe.select(df_described.columns) #forces the columns into the same order

expanded_describe = df_described.unionAll(new_describe)  #merges the new stats with the original describe
expanded_describe.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/spark/python/pyspark/sql/dataframe.py:1505: DeprecationWarning: Deprecated in 2.0, use union instead.
#   warnings.warn(&#34;Deprecated in 2.0, use union instead.&#34;, DeprecationWarning)
# +--------+------------------------+------------------------+--------------------+------------------+-----------------------------------+-----------------------------+---------------------+------------------+------------------+-------------------+-----------------------------------------+----------------------------+------------------+-------------------------+----------------------+--------------------+----------------------------+------------------------+--------------------+----------------------------------+--------------------------------+------------------------------+-------------------------------+------------------+----------------------+--------------------+---------+-------------------+
#  summary|Adult_obesity_percentage|Adult_smoking_percentage|All_Specialties_AAMC|Clinical_Care_rank|Emergency_Medicine_specialists_2019|Excessive_drinking_percentage|Health_Behaviors_rank| House_per_sq_mile|          ICU_Beds|Length_of_Life_rank|Med_HH_Income_Percent_of_State_Total_2018|Median_Household_Income_2018| POP_ESTIMATE_2018|Physical_Environment_rank|Population_per_sq_mile|Quality_of_Life_rank|Social_Economic_Factors_rank|Surgery_specialists_2019|Total_Hospitals_2019|Total_Primary_Care_Physicians_2019|Total_Specialist_Physicians_2019|Total_nurse_practitioners_2019|Total_physician_assistants_2019|   Unemployed_2019|Unemployment_rate_2019|               cases|   county|              label|
# kurtosis|      0.5235663388625418|       2.423224982545177|  14.468154845472782| 4.017975712907111|                  3.561727916341921|         0.014320400789793908|    4.019714534274933|191.96151317133055|2190.8986988929532|   4.37005593755238|                         4.33035562176173|          3.9156612073332377|310.56575386995496|        3.931636227904445|     171.1385861529977|  4.0794287584919084|            4.18519170141111|      10.015850138080602|  1.5986510181956497|                 7.217673531343301|              11.971662380288494|            1.2392835500043384|             -0.661695938012234| 497.7956686450704|    11.328895935631742|   167.3470216050706|     None|  38.98841964641258|
# +--------+------------------------+------------------------+--------------------+------------------+-----------------------------------+-----------------------------+---------------------+------------------+------------------+-------------------+-----------------------------------------+----------------------------+------------------+-------------------------+----------------------+--------------------+---------------

# %%
label = df[['label']].collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print(label[:5])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[Row(label=0.5833625014584063), Row(label=0.08473657094823613), Row(label=0.12887013112535842), Row(label=0.0), Row(label=0.10626992561105207)]
# </div>

# %%
df.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[25]: [&#39;Adult_obesity_percentage&#39;,
#  &#39;Adult_smoking_percentage&#39;,
#  &#39;All_Specialties_AAMC&#39;,
#  &#39;Clinical_Care_rank&#39;,
#  &#39;Emergency_Medicine_specialists_2019&#39;,
#  &#39;Excessive_drinking_percentage&#39;,
#  &#39;Health_Behaviors_rank&#39;,
#  &#39;House_per_sq_mile&#39;,
#  &#39;ICU_Beds&#39;,
#  &#39;Length_of_Life_rank&#39;,
#  &#39;Med_HH_Income_Percent_of_State_Total_2018&#39;,
#  &#39;Median_Household_Income_2018&#39;,
#  &#39;POP_ESTIMATE_2018&#39;,
#  &#39;Physical_Environment_rank&#39;,
#  &#39;Population_per_sq_mile&#39;,
#  &#39;Quality_of_Life_rank&#39;,
#  &#39;Social_Economic_Factors_rank&#39;,
#  &#39;Surgery_specialists_2019&#39;,
#  &#39;Total_Hospitals_2019&#39;,
#  &#39;Total_Primary_Care_Physicians_2019&#39;,
#  &#39;Total_Specialist_Physicians_2019&#39;,
#  &#39;Total_nurse_practitioners_2019&#39;,
#  &#39;Total_physician_assistants_2019&#39;,
#  &#39;Unemployed_2019&#39;,
#  &#39;Unemployment_rate_2019&#39;,
#  &#39;cases&#39;,
#  &#39;county&#39;,
#  &#39;label&#39;]</div>

# %%
df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[26]: [(&#39;Adult_obesity_percentage&#39;, &#39;double&#39;),
#  (&#39;Adult_smoking_percentage&#39;, &#39;double&#39;),
#  (&#39;All_Specialties_AAMC&#39;, &#39;double&#39;),
#  (&#39;Clinical_Care_rank&#39;, &#39;double&#39;),
#  (&#39;Emergency_Medicine_specialists_2019&#39;, &#39;double&#39;),
#  (&#39;Excessive_drinking_percentage&#39;, &#39;double&#39;),
#  (&#39;Health_Behaviors_rank&#39;, &#39;double&#39;),
#  (&#39;House_per_sq_mile&#39;, &#39;double&#39;),
#  (&#39;ICU_Beds&#39;, &#39;double&#39;),
#  (&#39;Length_of_Life_rank&#39;, &#39;double&#39;),
#  (&#39;Med_HH_Income_Percent_of_State_Total_2018&#39;, &#39;double&#39;),
#  (&#39;Median_Household_Income_2018&#39;, &#39;double&#39;),
#  (&#39;POP_ESTIMATE_2018&#39;, &#39;double&#39;),
#  (&#39;Physical_Environment_rank&#39;, &#39;double&#39;),
#  (&#39;Population_per_sq_mile&#39;, &#39;double&#39;),
#  (&#39;Quality_of_Life_rank&#39;, &#39;double&#39;),
#  (&#39;Social_Economic_Factors_rank&#39;, &#39;double&#39;),
#  (&#39;Surgery_specialists_2019&#39;, &#39;double&#39;),
#  (&#39;Total_Hospitals_2019&#39;, &#39;double&#39;),
#  (&#39;Total_Primary_Care_Physicians_2019&#39;, &#39;double&#39;),
#  (&#39;Total_Specialist_Physicians_2019&#39;, &#39;double&#39;),
#  (&#39;Total_nurse_practitioners_2019&#39;, &#39;double&#39;),
#  (&#39;Total_physician_assistants_2019&#39;, &#39;double&#39;),
#  (&#39;Unemployed_2019&#39;, &#39;double&#39;),
#  (&#39;Unemployment_rate_2019&#39;, &#39;double&#39;),
#  (&#39;cases&#39;, &#39;double&#39;),
#  (&#39;county&#39;, &#39;string&#39;),
#  (&#39;label&#39;, &#39;double&#39;)]</div>

# %%
#drop county since it is string and is not a numerical feature
df = df.drop("county")
df_temp=df_temp.drop("county")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df = df.dropna()
df_temp=df_temp.dropna()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Adult_obesity_percentage</th><th>Adult_smoking_percentage</th><th>All_Specialties_AAMC</th><th>Clinical_Care_rank</th><th>Emergency_Medicine_specialists_2019</th><th>Excessive_drinking_percentage</th><th>Health_Behaviors_rank</th><th>House_per_sq_mile</th><th>ICU_Beds</th><th>Length_of_Life_rank</th><th>Med_HH_Income_Percent_of_State_Total_2018</th><th>Median_Household_Income_2018</th><th>POP_ESTIMATE_2018</th><th>Physical_Environment_rank</th><th>Population_per_sq_mile</th><th>Quality_of_Life_rank</th><th>Social_Economic_Factors_rank</th><th>Surgery_specialists_2019</th><th>Total_Hospitals_2019</th><th>Total_Primary_Care_Physicians_2019</th><th>Total_Specialist_Physicians_2019</th><th>Total_nurse_practitioners_2019</th><th>Total_physician_assistants_2019</th><th>Unemployed_2019</th><th>Unemployment_rate_2019</th><th>cases</th><th>label</th></tr></thead><tbody><tr><td>40.0</td><td>21.0</td><td>2.2945925621281065</td><td>41.0</td><td>0.14319075819624313</td><td>13.0</td><td>44.0</td><td>19.0</td><td>0.0</td><td>41.0</td><td>63.29767965</td><td>33199.0</td><td>17142.0</td><td>41.0</td><td>46.9</td><td>46.0</td><td>42.0</td><td>0.1581392439621981</td><td>0.013571651557577879</td><td>1.257836399486641</td><td>1.2690477639715319</td><td>0.4171807667133357</td><td>0.20632844143040488</td><td>266.0</td><td>4.0</td><td>7.117022517792556</td><td>0.5833625014584063</td></tr><tr><td>32.0</td><td>16.0</td><td>2.2945925621627485</td><td>6.0</td><td>0.14319075822283683</td><td>19.0</td><td>11.0</td><td>163.0</td><td>0.18642045608611948</td><td>9.0</td><td>115.5922897</td><td>60627.0</td><td>295032.0</td><td>7.0</td><td>375.4</td><td>10.0</td><td>3.0</td><td>0.158139243980314</td><td>0.013571651532715095</td><td>1.2578363994414166</td><td>1.2690477636324196</td><td>0.4171807668320725</td><td>0.20632844145719786</td><td>3510.0</td><td>2.3</td><td>1.667615716261287</td><td>0.08473657094823613</td></tr><tr><td>44.0</td><td>20.0</td><td>2.294592562260382</td><td>44.0</td><td>0
#  &#39;Social_Economic_Factors_rank&#39;,
#  &#39;Surgery_specialists_2019&#39;,
#  &#39;Total_Hospitals_2019&#39;,
#  &#39;Total_Primary_Care_Physicians_2019&#39;,
#  &#39;Total_Specialist_Physicians_2019&#39;,
#  &#39;Total_nurse_practitioners_2019&#39;,
#  &#39;Total_physician_assistants_2019&#39;,
#  &#39;Unemployed_2019&#39;,
#  &#39;Unemployment_rate_2019&#39;,
#  &#39;cases&#39;,
#  &#39;label&#39;]</div>

# %%
from pyspark.ml import Pipeline
from pyspark.ml.regression import DecisionTreeRegressor
from pyspark.ml.feature import VectorIndexer
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.sql import Row
from pyspark.ml.linalg import Vectors
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df=df.rdd.map(lambda x:(Vectors.dense(x[0:-1]), x[-1])).toDF(["features", "label"])
df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+--------------------+
#             features|               label|
# +--------------------+--------------------+
# [40.0,21.0,2.2945...|  0.5833625014584063|
# [32.0,16.0,2.2945...| 0.08473657094823613|
# [44.0,20.0,2.2945...| 0.12887013112535842|
# [39.0,21.0,2.2945...|                 0.0|
# [34.0,17.0,2.2945...| 0.10626992561105207|
# [36.0,18.0,2.2945...| 0.02596053997923157|
# [32.0,17.0,2.2945...|                 0.0|
# [41.0,17.0,2.2945...|0.023005958543262706|
# [32.0,17.0,2.2945...|0.008004034033152708|
# [33.0,16.0,2.2945...|   0.142314075103238|
# [38.0,19.0,2.2945...|                 0.0|
# [32.0,17.0,2.2945...| 0.04141604648791926|
# [38.0,18.0,2.2945...|  0.1220519753642782|
# [39.0,19.0,2.2945...|                 0.0|
# [42.0,19.0,2.2945...|  0.2940599882376005|
# [32.0,15.0,2.2945...|0.018240319862249103|
# [37.0,12.0,2.4041...|                 0.0|
# [36.0,16.0,2.4041...| 0.10591537361648043|
# [40.0,15.0,2.4041...|                 0.0|
# [28.0,13.0,2.4041...|                 0.0|
# +--------------------+--------------------+
# only showing top 20 rows
#
# </div>

# %%
# Automatically identify categorical features, and index them.
# We specify maxCategories so features with > 4 distinct values are treated as continuous.
featureIndexer = VectorIndexer(inputCol="features", outputCol="indexedFeatures", maxCategories=4).fit(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Split the data into training and test sets (30% held out for testing)
(trainingData, testData) = df.randomSplit([0.7, 0.3])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Train a DecisionTree model.
dt = DecisionTreeRegressor(featuresCol="indexedFeatures")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Chain indexer and tree in a Pipeline
pipeline = Pipeline(stages=[featureIndexer, dt])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Train model.  This also runs the indexer.
model = pipeline.fit(trainingData)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Make predictions.
predictions = model.transform(testData)

# Select example rows to display.
predictions.select("prediction", "label", "features").show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+--------------------+--------------------+
#           prediction|               label|            features|
# +--------------------+--------------------+--------------------+
#  0.09376898510195876| 0.05765798086555841|[22.0,12.0,2.2483...|
#  0.09376898510195876|0.043153856444381154|[22.0,15.0,2.5307...|
#  0.48947626040137054|  0.7199424046076314|[22.0,16.0,2.2483...|
#  0.22215278919992346|  0.2724300762804214|[22.0,23.0,2.5307...|
# 0.010582524537614709|                 0.0|[24.0,14.0,2.4041...|
# +--------------------+--------------------+--------------------+
# only showing top 5 rows
#
# </div>

# %%
display(predictions)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>features</th><th>label</
 1.4923168507083182, 0.8490386276788958, 0.17607064093715946, 168.0, 3.1, 125.40864511442064))</td><td>0.22215278919992346</td></tr><tr><td>List(1, 26, List(), List(24.0, 14.0, 2.4041213511070945, 16.0, 0.06574212065070041, 18.0, 23.0, 2.3, 0.0, 31.0, 87.87188163, 50123.0, 2213.0, 40.0, 4.2, 17.0, 8.0, 0.1394186357885224, 0.06460863624039766, 1.2275640845006779, 1.0858784789877993, 0.5361383303208315, 0.4579278761861726, 37.0, 3.1, 0.4518752824220515))</td><td>0.0</td><td>List(1, 26, List(), List(24.0, 14.0, 2.4041213511070945, 16.0, 0.06574212065070041, 18.0, 23.0, 2.3, 0.0, 31.0, 87.87188163, 50123.0, 2213.0, 40.0, 4.2, 17.0, 8.0, 0.1394186357885224, 0.06460863624039766, 1.2275640845006779, 1.0858784789877993, 0.5361383303208315, 0.4579278761861726, 37.0, 3.1, 0.4518752824220515))</td><td>0.010582524537614709</td></tr><tr><td>List(1, 26, List(), List(24.0, 15.0, 2.2483920458429676, 224.0, 0.11354670755001509, 20.0, 68.0, 4.4,  ...

# %%
predictions.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[44]: [(&#39;features&#39;, &#39;vector&#39;),
#  (&#39;label&#39;, &#39;double&#39;),
#  (&#39;indexedFeatures&#39;, &#39;vector&#39;),
#  (&#39;prediction&#39;, &#39;double&#39;)]</div>

# %%
pandas_df_temp = df_temp.toPandas()
pandas_predictions = predictions.toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/spark/python/pyspark/sql/types.py:1636: DeprecationWarning: Using or importing the ABCs from &#39;collections&#39; instead of from &#39;collections.abc&#39; is deprecated, and in 3.8 it will stop working
#   return pa.schema(fields)
# /databricks/spark/python/pyspark/sql/dataframe.py:2165: UserWarning: toPandas attempted Arrow optimization because &#39;spark.sql.execution.arrow.enabled&#39; is set to true; however, failed by the reason below:
#   Unsupported type in conversion to Arrow: VectorUDT
# Attempting non-optimization as &#39;spark.sql.execution.arrow.fallback.enabled&#39; is set to true.
#   warnings.warn(msg)
# </div>

# %%
pandas_predictions['prediction_de_nom'] = (pandas_predictions['prediction']*pandas_df_temp['POP_ESTIMATE_2018'])/1000
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pandas_predictions['label_de_nom'] = (pandas_predictions['label']*pandas_df_temp['POP_ESTIMATE_2018'])/1000
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pandas_predictions['prediction_de_nom'] = pandas_predictions['prediction_de_nom'].apply(lambda x: round(x))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pandas_predictions['label_de_nom'] = pandas_predictions['label_de_nom'].apply(lambda x: round(x))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(pandas_predictions)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>features</th><th>label</th><th>indexedFeatures</th><th>prediction</th><th>prediction_de_nom</th><th>label_de_nom</th></tr></thead><tbody><tr><td>List(1, 26, List(), List(22.0, 12.0, 2.2483920462417006, 3.0, 0.11354670752909125, 25.0, 18.0, 445.6, 0.23543675520103016, 5.0, 125.7669218, 76255.0, 1248743.0, 215.0, 1034.4, 9.0, 30.0, 0.12114203811352696, 0.01822182511533598, 1.069757014053332, 1.1810390584772046, 0.34492556138452823, 0.20357576314742104, 19047.0, 2.6, 1.8322425030610783))</td><td>0.05765798086555841</td><td>List(1, 26, List(), List(22.0, 12.0, 2.2483920462417006, 3.0, 0.11354670752909125, 25.
065070041, 18.0, 23.0, 2.3, 0.0, 31.0, 87.87188163, 50123.0, 2213.0, 40.0, 4.2, 17.0, 8.0, 0.1394186357885224, 0.06460863624039766, 1.2275640845006779, 1.0858784789877993, 0.5361383303208315, 0.4579278761861726, 37.0, 3.1, 0.4518752824220515))</td><td>0.0</td><td>List(1, 26, List(), List(24.0, 14.0, 2.4041213511070945, 16.0, 0.06574212065070041, 18.0, 23.0, 2.3, 0.0, 31.0, 87.87188163, 50123.0, 2213.0, 40.0, 4.2, 17.0, 8.0, 0.1394186357885224, 0.06460863624039766, 1.2275640845006779, 1.0858784789877993, 0.5361383303208315, 0.4579278761861726, 37.0, 3.1, 0.4518752824220515))</td><td>0.0105825 ...

# %%
# Select (prediction, true label) and compute test error
evaluator = RegressionEvaluator(
    labelCol="label", predictionCol="prediction", metricName="rmse")
rmse = evaluator.evaluate(predictions)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Root Mean Squared Error (RMSE) on test data = 0.191601
# </div>

# %%
treeModel = model.stages[1]
# summary only
print(treeModel)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DecisionTreeRegressionModel (uid=DecisionTreeRegressor_9bb9752af5bd) of depth 5 with 63 nodes
# </div>

# %%
display(treeModel)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>treeNode</th></tr></thead><tbody><tr><td>{"index":31,"featureType":"continuous","prediction":null,"threshold":4.354532061735112,"categories":null,"feature":25,"overflow":false}</td></tr><tr><td>{"index":15,"featureType":"continuous","prediction":null,"threshold":1.7087879475080885,"categories":null,"feature":25,"overflow":false}</td></tr><tr><td>{"index":7,"featureType":"continuous","prediction":null,"threshold":0.7818929879908421,"categories":null,"feature":25,"overflow":false}</td></tr><tr><td>{"index":3,"featureType":"continuous","prediction":null,"threshold":0.2637752502671016,"categories":null,"feature":25,"overflow":false}</td></tr><tr><td>{"index":1,"featureType":"continuous","prediction":null,"threshold":32778.0,"categories":null,"feature":12,"overflow":false}</td></tr><tr><td>{"index":0,"featureType":null,"prediction":0.0012319038986450127,"threshold":null,"categories":null,"feature":null,"overflow":false}</td></tr><tr><td>{"index":2,"featureType":null,"prediction":0.007280124193144118,"threshold":null,"categories":null,"feature":null,"overflow":false}</td></tr><tr><td>{"index":5,"featureType":"continuous","prediction":null,"threshold":4.05,"categories":null,"feature":24,"overflow":false}</td></tr><tr><td>{"index":4,"featureType":null,"prediction":0.010582524537614709,"threshold":null,"categories":null,"feature":null,"overflow":false}</td></tr><tr><td>{"index":6,"featureType":null,"prediction":0.020503345212901206,"threshold":null,"categories":null,"feature":null,"overflow":false}</td></tr><tr><td>{"index":11,"featureType":"continuous","prediction":null,"threshold":1.5111853882832924,"categories":null,"feature":25,"overflow":false}</td></tr><tr><td>{"index":9,"featureType":"continuous","prediction":null,"threshold":0.03738738234693044,"categories":null,"feature":18,"overflow":false}</td></tr><tr><td>{"index":8,"featureType":null,"prediction":0.038457934815250644,"threshold":null,"categories":null,"feature":null,"overflow":false}</td></tr><tr><td>{"index":10,"featureType":null,"prediction":0.011952009432522667,"threshold":null,"categories":null,"feature":null,"overflow":false}</td></tr><tr><td>{"index":13,"featureType":"continuous","prediction":null,"threshold":21.5,"categories":null,"feature":5,"overflow":false}</td></tr><tr><td>{"index":12,"featureType":null,"prediction":0.05780218243623141,"threshold":null,"categories":null,"feature":null,"overflow":false}</td></tr><tr><td>{"index":14,"featureType":null,"prediction":0.14439193104049436,"threshold":null,"categories":null,"feature":null,"overflow":false}</td></tr><tr><td>{"index":23,"featureType":"continuous","prediction":null,"threshold":2.715954889053698,"categories":null,"feature":25,"overflow":false}</td></tr><tr><td>{"index":19,"featureType":"continuous","prediction":null,"threshold":25.95,"categories":null,"feature":7,"overflow":false}</td></tr><tr><td>{"index":17,"featureType":"continuous","prediction":null,"threshold":40446.5,"categories":null,"feature":11,"overflow":false}</td></tr><tr><td>{"index":16,"featureType":null,"prediction":0.10268482104084742,"threshold":null,"categories":null,"feature":null,"overflow":false}</td></tr><tr><td>{"index":18,"featureType":null,"prediction":0.04215604578387776,"threshold":null,"categories":null,"feature":null,"overflow":false}</td></tr><tr><td>{"index":21,"featureType":"continuous","prediction":null,"threshold":0.1673445099578305,"categories":null,"feature":4,"overflow":false}</td></tr><tr><td>{"index":20,"featureType":null,"prediction":0.09376898510195876,"threshold":null,"categories":null,"feature":null,"overflow":false}</td></tr><tr><td>{"index":22,"featureType":null,"prediction":0.14278132257703152,"threshold":null,"categories":null,"feature":null,"overflow":false}</td></tr><tr><td>{"index":27,"featureType":"continuous","prediction":null,"threshold":0.11981112471924213,"categories":null,"feature":4," ...

# %%
#print the nodes of the decision tree model
print(treeModel.toDebugString)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DecisionTreeRegressionModel (uid=DecisionTreeRegressor_9bb9752af5bd) of depth 5 with 63 nodes
#   If (feature 25 &lt;= 4.354532061735112)
#    If (feature 25 &lt;= 1.7087879475080885)
#     If (feature 25 &lt;= 0.7818929879908421)
#      If (feature 25 &lt;= 0.2637752502671016)
#       If (feature 12 &lt;= 32778.0)
#        Predict: 0.0012319038986450127
#       Else (feature 12 &gt; 32778.0)
#        Predict: 0.007280124193144118
#      Else (feature 25 &gt; 0.2637752502671016)
#       If (feature 24 &lt;= 4.05)
#        Predict: 0.010582524537614709
#       Else (feature 24 &gt; 4.05)
#        Predict: 0.020503345212901206
#     Else (feature 25 &gt; 0.7818929879908421)
#      If (feature 25 &lt;= 1.5111853882832924)
#       If (feature 18 &lt;= 0.03738738234693044)
#        Predict: 0.038457934815250644
#       Else (feature 18 &gt; 0.03738738234693044)
#        Predict: 0.011952009432522667
#      Else (feature 25 &gt; 1.5111853882832924)
#       If (feature 5 &lt;= 21.5)
#        Predict: 0.05780218243623141
#       Else (feature 5 &gt; 21.5)
#        Predict: 0.14439193104049436
#    Else (feature 25 &gt; 1.7087879475080885)
#     If (feature 25 &lt;= 2.715954889053698)
#      If (feature 7 &lt;= 25.95)
#       If (feature 11 &lt;= 40446.5)
#        Predict: 0.10268482104084742
#       Else (feature 11 &gt; 40446.5)
#        Predict: 0.04215604578387776
#      Else (feature 7 &gt; 25.95)
#       If (feature 4 &lt;= 0.1673445099578305)
#        Predict: 0.09376898510195876
#       Else (feature 4 &gt; 0.1673445099578305)
#        Predict: 0.14278132257703152
#     Else (feature 25 &gt; 2.715954889053698)
#      If (feature 4 &lt;= 0.11981112471924213)
#       If (feature 0 &lt;= 24.5)
#        Predict: 0.48947626040137054
#       Else (feature 0 &gt; 24.5)
#        Predict: 0.07256662436755976
#      Else (feature 4 &gt; 0.11981112471924213)
#       If (feature 25 &lt;= 3.603268711825028)
#        Predict: 0.14938692247345875
#       Else (feature 25 &gt; 3.603268711825028)
#        Predict: 0.23240547281990473
#   Else (feature 25 &gt; 4.354532061735112)
#    If (feature 7 &lt;= 590.25)
#     If (feature 6 &lt;= 115.5)
#      If (feature 4 &lt;= 0.1673445099578305)
#       If (feature 19 &lt;= 1.2266130040224172)
#        Predict: 0.3926888041782725
#       Else (feature 19 &gt; 1.2266130040224172)
#        Predict: 0.22215278919992346
#      Else (feature 4 &gt; 0.1673445099578305)
#       If (feature 16 &lt;= 50.5)
#        Predict: 0.5771401837490935
#       Else (feature 16 &gt; 50.5)
#        Predict: 0.19818613297181192
#     Else (feature 6 &gt; 115.5)
#      If (feature 19 &lt;= 1.1905537111153541)
#       If (feature 9 &lt;= 110.5)
#        Predict: 0.956939774609421
#       Else (feature 9 &gt; 110.5)
#        Predict: 0.1891754140961729
#      Else (feature 19 &gt; 1.1905537111153541)
#       If (feature 11 &lt;= 36572.0)
#        Predict: 2.808614675419813
#       Else (feature 11 &gt; 36572.0)
#        Predict: 0.994793959375072
#    Else (feature 7 &gt; 590.25)
#     If (feature 21 &lt;= 0.5577453313430967)
#      If (feature 21 &lt;= 0.5082903115278377)
#       If (feature 11 &lt;= 51555.5)
#        Predict: 1.1331357565005933
#       Else (feature 11 &gt; 51555.5)
#        Predict: 0.6018619648049782
#      Else (feature 21 &gt; 0.5082903115278377)
#       If (feature 4 &lt;= 0.17824345970039707)
#        Predict: 0.3130218612943442
#       Else (feature 4 &gt; 0.17824345970039707)
#        Predict: 0.6010232712076808
#     Else (feature 21 &gt; 0.5577453313430967)
#      If (feature 24 &lt;= 3.25)
#       If (feature 5 &lt;= 18.5)
#        Predict: 1.2456756986421382
#       Else (feature 5 &gt; 18.5)
#        Predict: 0.908585568136623
#      Else (feature 24 &gt; 3.25)
#       If (feature 3 &lt;= 2.5)
#        Predict: 1.8169195851121551
#       Else (feature 3 &gt; 2.5)
#        Predict: 1.5225050299860592
#
# </div>

# %%
def extract_feature_imp(feature_imp, dataset, features_col): 
  """Affiche pour chaque features d'un modèle son nom correspondant et les trie dans l'ordre d'importance""" 
  list_extract = [] 
  for i in dataset.schema[features_col].metadata["ml_attr"]["attrs"]: 
    list_extract = list_extract + dataset.schema[features_col].metadata["ml_attr"]["attrs"][i] 
    varlist = pd.DataFrame(list_extract) 
    varlist['score'] = varlist['idx'].apply(lambda x: feature_imp[x]) * 100 
    return varlist.sort_values('score', ascending=False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
grid = ParamGridBuilder() \
  .addGrid(dt.maxDepth, [2, 3, 4, 5, 6, 7, 8]) \
  .addGrid(dt.maxBins, [2, 4, 8]) \
  .build()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
cv = CrossValidator(estimator=pipeline, evaluator=evaluator, estimatorParamMaps=grid, numFolds=3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Explicitly create a new run.
# This allows this cell to be run multiple times.
# If you omit mlflow.start_run(), then this cell could run once,
# but a second run would hit conflicts when attempting to overwrite the first run.
import mlflow
import mlflow
import mlflow.mleap
import pyspark
#import pyspark.ml.mleap.SparkUtil 
#import mlflow.mleap.SparkUtil 
import mlflow.mleap
with mlflow.start_run():
  cvModel = cv.fit(trainingData)
  mlflow.set_tag('owner_team', 'UX Data Science') # Logs user-defined tags
  test_metric = evaluator.evaluate(cvModel.transform(testData))
  mlflow.log_metric('testData_' + evaluator.getMetricName(), test_metric) # Logs additional metrics
  mlflow.mleap.log_model(spark_model=cvModel.bestModel, sample_input=testData, artifact_path='dbfs:/databricks/mlflow/2835302286394144') # Logs the best model via mleap
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">MLlib will automatically track trials in MLflow. After your tuning fit() call has completed, view the MLflow UI to see logged runs.
# </div>
