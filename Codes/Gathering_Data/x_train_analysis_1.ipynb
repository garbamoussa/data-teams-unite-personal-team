# %% [markdown]
# ## Overview
#
# This notebook will show you how to create and query a table or DataFrame that you uploaded to DBFS. [DBFS](https://docs.databricks.com/user-guide/dbfs-databricks-file-system.html) is a Databricks File System that allows you to store data for querying inside of Databricks. This notebook assumes that you have a file already inside of DBFS that you would like to read from.
#
# This notebook is written in **Python** so the default cell type is Python. However, you can use different languages by using the `%LANGUAGE` syntax. Python, Scala, SQL, and R are all supported.

# %%
# File location and type
#file_location = "/FileStore/tables/health_factors.csv"
file_location = "/FileStore/tables/Train_X.csv"
file_type = "csv"

# CSV options
infer_schema = "true"
first_row_is_header = "true"
delimiter = ","

# The applied options are for CSV files. For other file types, these will be ignored.
df = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location)

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>Active.Physicians.per.100.000.Population..2018..AAMC.</th><th>Total.Active.Patient.Care.Physicians.per.100.000.Population..2018..AAMC.</th><th>Active.Primary.Care.Physicians.per.100.000.Population..2018..AAMC.</th><th>Active.Patient.Care.Primary.Care.Physicians.per.100.000.Population..2018..AAMC.</th><th>Active.General.Surgeons.per.100.000.Population..2018..AAMC.</th><th>Active.Patient.Care.General.Surgeons.per.100.000.Population..2018..AAMC.</th><th>Percentage.of.Active.Physicians.Who.Are.Female..2018..AAMC.</th><th>Percentage.of.Active.Physicians.Who.Are.International.Medical.Graduates..IMGs...2018..AAMC.</th><th>Percentage.of.Active.Physicians.Who.Are.Age.60.or.Older..2018..AAMC.</th><th>MD.and.DO.Student.Enrollment.per.100.000.Population..AY.2018.2019..AAMC.</th><th>Student.Enrollment.at.Public.MD.and.DO.Schools.per.100.000.Population..AY.2018.2019..AAMC.</th><th>Percentage.Change.in.Student.Enrollment.at.MD.and.DO.Schools..2008.2018..AAMC.</th><th>Percentage.of.MD.Students.Matriculating.In.State..AY.2018.2019..AAMC.</th><th>Total.Residents.Fellows.in.ACGME.Programs.per.100.000.Population.as.of.December.31..2018..AAMC.</th><th>Total.Residents.Fellows.in.Primary.Care.ACGME.Programs.per.100.000.Population.as.of.Dec..31..2018..AAMC.</th><th>Percentage.of.Residents.in.ACGME.Programs.Who.Are.IMGs.as.of.December.31..2018..AAMC.</th><th>Ratio.of.Residents.and.Fellows..GME..to.Medical.Students..UME...AY.2017.2018..AAMC.</th><th>Percent.Change.in.Residents.and.Fellows.in.ACGME.Accredited.Programs..2008.2018..AAMC.</th><th>Percentage.of.Physicians.Retained.in.State.from.Undergraduate.Medical.Education..UME...2018..AAMC.</th><th>All.Specialties..AAMC.</th><th>State.Local.Government.hospital.beds.per.1000.people..2019.</th><th>Non.profit.hospital.beds.per.1000.people..2019.</th><th>For.profit.hospital.beds.per.1000.people..2019.</th><th>Total.hospital.beds.per.1000.people..2019.</th><th>Total.nurse.practitioners..2019.</th><th>Total.physician.assistants..2019.</th><th>Total.Hospitals..2019.</th><th>Total.Primary.Care.Physicians..2019.</th><th>Surgery.specialists..2019.</th><th>Emergency.Medicine.specialists..2019.</th><th>Total.Specialist.Physicians..2019.</th><th>ICU.Beds</th><th>Length.of.Life.rank</th><th>Quality.of.Life.rank</th><th>Health.Behaviors.rank</th><th>Clinical.Care.rank</th><th>Social...Economic.Factors.rank</th><th>Physical.Environment.rank</th><th>Adult.smoking.percentage</th><th>Adult.obesity.percentage</th><th>Excessive.drinking.percentage</th><th>Population.per.sq.mile</th><th>House.per.sq.mile</th><th>Share.of.Tests.with.Positive.COVID.19.Results</th><th>Number.of.Tests.with.Results.per.1.000.Population</th></tr></thead><tbody><tr><td>657</td><td>284.4</td><td>240.5</td><td>99.6</td><td>87.2</td><td>7.0</td><td>5.8</td><td>38.7</td><td>30.7</td><td>30.4</td><td>44.7</td><td>13.4</td><td>2.5</td><td>62.6</td><td>49.1</td><td>19.8</td><td>25.9</td><td>1.2</td><td>7.1</td><td>30.9</td><td>2.8443428657820573</td><td>0.1</td><td>2.2</td><td>0.2</td><td>2.5</td><td>0.38952741838891497</td><td>0.195587815171442</td><td>0.014676934769845</td><td>1.72614880342884</td><td>0.16113233730624707</td><td>0.20767470261860027</td><td>1.678350657585721</td><td>0.0</td><td>31.0</td><td>37.0</td><td>14.0</td><td>56.0</td><td>26.0</td><td>21.0</td><td>15.0</td><td>26.0</td><td>20.0</td><td>32.6</td><td>14.2</td><td>0.17307899999999998</td><td>38.6</td></tr><tr><td>1331</td><td>302.7</td><td>265.0</td><td>104.9</td><td>96.0</td><td>7.4</td><td>6.6</td><td>37.2</td><td>17.2</td><td>27.9</td><td>24.2</td><td>18.1</td><td>29.7</td><td>54.3</td><td>41.9</td><td>13.4</td><td>17.5</td><td>1.7</td><td>7.0</td><td>52.0</td><td>3.026814863838211</td><td>0.3</td><td>2.2</td><td>0.4802056555269882</td><td>2.5</td><td>0.5132611167941791</td><td>0.32292678599325886</td><td>0.022633389545770693</td><td>1.566159268631962< ...

# %%
from pyspark import SparkContext

#sc = SparkContext()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- _c0: integer (nullable = true)
# -- Active.Physicians.per.100.000.Population..2018..AAMC.: double (nullable = true)
# -- Total.Active.Patient.Care.Physicians.per.100.000.Population..2018..AAMC.: double (nullable = true)
# -- Active.Primary.Care.Physicians.per.100.000.Population..2018..AAMC.: double (nullable = true)
# -- Active.Patient.Care.Primary.Care.Physicians.per.100.000.Population..2018..AAMC.: double (nullable = true)
# -- Active.General.Surgeons.per.100.000.Population..2018..AAMC.: double (nullable = true)
# -- Active.Patient.Care.General.Surgeons.per.100.000.Population..2018..AAMC.: double (nullable = true)
# -- Percentage.of.Active.Physicians.Who.Are.Female..2018..AAMC.: double (nullable = true)
# -- Percentage.of.Active.Physicians.Who.Are.International.Medical.Graduates..IMGs...2018..AAMC.: double (nullable = true)
# -- Percentage.of.Active.Physicians.Who.Are.Age.60.or.Older..2018..AAMC.: double (nullable = true)
# -- MD.and.DO.Student.Enrollment.per.100.000.Population..AY.2018.2019..AAMC.: double (nullable = true)
# -- Student.Enrollment.at.Public.MD.and.DO.Schools.per.100.000.Population..AY.2018.2019..AAMC.: double (nullable = true)
# -- Percentage.Change.in.Student.Enrollment.at.MD.and.DO.Schools..2008.2018..AAMC.: double (nullable = true)
# -- Percentage.of.MD.Students.Matriculating.In.State..AY.2018.2019..AAMC.: double (nullable = true)
# -- Total.Residents.Fellows.in.ACGME.Programs.per.100.000.Population.as.of.December.31..2018..AAMC.: double (nullable = true)
# -- Total.Residents.Fellows.in.Primary.Care.ACGME.Programs.per.100.000.Population.as.of.Dec..31..2018..AAMC.: double (nullable = true)
# -- Percentage.of.Residents.in.ACGME.Programs.Who.Are.IMGs.as.of.December.31..2018..AAMC.: double (nullable = true)
# -- Ratio.of.Residents.and.Fellows..GME..to.Medical.Students..UME...AY.2017.2018..AAMC.: double (nullable = true)
# -- Percent.Change.in.Residents.and.Fellows.in.ACGME.Accredited.Programs..2008.2018..AAMC.: double (nullable = true)
# -- Percentage.of.Physicians.Retained.in.State.from.Undergraduate.Medical.Education..UME...2018..AAMC.: double (nullable = true)
# -- All.Specialties..AAMC.: double (nullable = true)
# -- State.Local.Government.hospital.beds.per.1000.people..2019.: double (nullable = true)
# -- Non.profit.hospital.beds.per.1000.people..2019.: double (nullable = true)
# -- For.profit.hospital.beds.per.1000.people..2019.: double (nullable = true)
# -- Total.hospital.beds.per.1000.people..2019.: double (nullable = true)
# -- Total.nurse.practitioners..2019.: double (nullable = true)
# -- Total.physician.assistants..2019.: double (nullable = true)
# -- Total.Hospitals..2019.: double (nullable = true)
# -- Total.Primary.Care.Physicians..2019.: double (nullable = true)
# -- Surgery.specialists..2019.: double (nullable = true)
# -- Emergency.Medicine.specialists..2019.: double (nullable = true)
# -- Total.Specialist.Physicians..2019.: double (nullable = true)
# -- ICU.Beds: double (nullable = true)
# -- Length.of.Life.rank: double (nullable = true)
# -- Quality.of.Life.rank: double (nullable = true)
# -- Health.Behaviors.rank: double (nullable = true)
# -- Clinical.Care.rank: double (nullable = true)
# -- Social...Economic.Factors.rank: double (nullable = true)
# -- Physical.Environment.rank: double (nullable = true)
# -- Adult.smoking.percentage: double (nullable = true)
# -- Adult.obesity.percentage: double (nullable = true)
# -- Excessive.drinking.percentage: double (nullable = true)
# -- Population.per.sq.mile: double (nullable = true)
# -- House.per.sq.mile: double (nullable = true)
# -- Share.of.Tests.with.Positive.COVID.19.Results: double (nullable = true)
# -- Number.of.Tests.with.Results.per.1.000.Population: double (nullable = true)
#
# </div>

# %%
df.head(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: [Row(_c0=657, Active.Physicians.per.100.000.Population..2018..AAMC.=284.4, Total.Active.Patient.Care.Physicians.per.100.000.Population..2018..AAMC.=240.5, Active.Primary.Care.Physicians.per.100.000.Population..2018..AAMC.=99.6, Active.Patient.Care.Primary.Care.Physicians.per.100.000.Population..2018..AAMC.=87.2, Active.General.Surgeons.per.100.000.Population..2018..AAMC.=7.0, Active.Patient.Care.General.Surgeons.per.100.000.Population..2018..AAMC.=5.8, Percentage.of.Active.Physicians.Who.Are.Female..2018..AAMC.=38.7, Percentage.of.Active.Physicians.Who.Are.International.Medical.Graduates..IMGs...2018..AAMC.=30.7, Percentage.of.Active.Physicians.Who.Are.Age.60.or.Older..2018..AAMC.=30.4, MD.and.DO.Student.Enrollment.per.100.000.Population..AY.2018.2019..AAMC.=44.7, Student.Enrollment.at.Public.MD.and.DO.Schools.per.100.000.Population..AY.2018.2019..AAMC.=13.4, Percentage.Change.in.Student.Enrollment.at.MD.and.DO.Schools..2008.2018..AAMC.=2.5, Percentage.of.MD.Students.Matriculating.In.State..AY.2018.2019..AAMC.=62.6, Total.Residents.Fellows.in.ACGME.Programs.per.100.000.Population.as.of.December.31..2018..AAMC.=49.1, Total.Residents.Fellows.in.Primary.Care.ACGME.Programs.per.100.000.Population.as.of.Dec..31..2018..AAMC.=19.8, Percentage.of.Residents.in.ACGME.Programs.Who.Are.IMGs.as.of.December.31..2018..AAMC.=25.9, Ratio.of.Residents.and.Fellows..GME..to.Medical.Students..UME...AY.2017.2018..AAMC.=1.2, Percent.Change.in.Residents.and.Fellows.in.ACGME.Accredited.Programs..2008.2018..AAMC.=7.1, Percentage.of.Physicians.Retained.in.State.from.Undergraduate.Medical.Education..UME...2018..AAMC.=30.9, All.Specialties..AAMC.=2.8443428657820573, State.Local.Government.hospital.beds.per.1000.people..2019.=0.1, Non.profit.hospital.beds.per.1000.people..2019.=2.2, For.profit.hospital.beds.per.1000.people..2019.=0.2, Total.hospital.beds.per.1000.people..2019.=2.5, Total.nurse.practitioners..2019.=0.38952741838891497, Total.physician.assistants..2019.=0.195587815171442, Total.Hospitals..2019.=0.014676934769845, Total.Primary.Care.Physicians..2019.=1.72614880342884, Surgery.specialists..2019.=0.16113233730624707, Emergency.Medicine.specialists..2019.=0.20767470261860027, Total.Specialist.Physicians..2019.=1.678350657585721, ICU.Beds=0.0, Length.of.Life.rank=31.0, Quality.of.Life.rank=37.0, Health.Behaviors.rank=14.0, Clinical.Care.rank=56.0, Social...Economic.Factors.rank=26.0, Physical.Environment.rank=21.0, Adult.smoking.percentage=15.0, Adult.obesity.percentage=26.0, Excessive.drinking.percentage=20.0, Population.per.sq.mile=32.6, House.per.sq.mile=14.2, Share.of.Tests.with.Positive.COVID.19.Results=0.17307899999999998, Number.of.Tests.with.Results.per.1.000.Population=38.6),
#  Row(_c0=1331, Active.Physicians.per.100.000.Population..2018..AAMC.=302.7, Total.Active.Patient.Care.Physicians.per.100.000.Population..2018..AAMC.=265.0, Active.Primary.Care.Physicians.per.100.000.Population..2018..AAMC.=104.9, Active.Patient.Care.Primary.Care.Physicians.per.100.000.Population..2018..AAMC.=96.0, Active.General.Surgeons.per.100.000.Population..2018..AAMC.=7.4, Active.Patient.Care.General.Surgeons.per.100.000.Population..2018..AAMC.=6.6, Percentage.of.Active.Physicians.Who.Are.Female..2018..AAMC.=37.2, Percentage.of.Active.Physicians.Who.Are.International.Medical.Graduates..IMGs...2018..AAMC.=17.2, Percentage.of.Active.Physicians.Who.Are.Age.60.or.Older..2018..AAMC.=27.9, MD.and.DO.Student.Enrollment.per.100.000.Population..AY.2018.2019..AAMC.=24.2, Student.Enrollment.at.Public.MD.and.DO.Schools.per.100.000.Population..AY.2018.2019..AAMC.=18.1, Percentage.Change.in.Student.Enrollment.at.MD.and.DO.Schools..2008.2018..AAMC.=29.7, Percentage.of.MD.Students.Matriculating.In.State..AY.2018.2019..AAMC.=54.3, Total.Residents.Fellows.in.ACGME.Programs.per.100.000.Population.as.of.December.31..2018..AAMC.=41.9, Total.Residents.Fellows.in.Primary.Care.ACGME.Programs.per.100.000.Population.as.of.Dec..31..2018..AAMC.=13.4, Percentage.of.Residents.in.ACGME.Programs.Who.Are.IMGs.as.of.December.31..2018..AAMC.=17.5, Ratio.of.Residents.and.Fellows..GME..to.Medical.Students..UME...AY.2017.2018..AAMC.=1.7, Percent.Change.in.Residents.and.Fellows.in.ACGME.Accredited.Programs..2008.2018..AAMC.=7.0, Percentage.of.Physicians.Retained.in.State.from.Undergraduate.Medical.Education..UME...2018..AAMC.=52.0, All.Specialties..AAMC.=3.026814863838211, State.Local.Government.hospital.beds.per.1000.people..2019.=0.3, Non.profit.hospital.beds.per.1000.people..2019.=2.2, For.profit.hospital.beds.per.1000.people..2019.=0.4802056555269882, Total.hospital.beds.per.1000.people..2019.=2.5, Total.nurse.practitioners..2019.=0.5132611167941791, Total.physician.assistants..2019.=0.32292678599325886, Total.Hospitals..2019.=0.022633389545770693, Total.Primary.Care.Physicians..2019.=1.566159268631962, Surgery.specialists..2019.=0.17696815590391096, Emergency.Medicine.specialists..2019.=0.16734450992456262, Total.Specialist.Physicians..2019.=1.6721975897490773, ICU.Beds=0.0, Length.of.Life.rank=15.0, Quality.of.Life.rank=43.0, Health.Behaviors.rank=39.0, Clinical.Care.rank=46.0, Social...Economic.Factors.rank=58.0, Physical.Environment.rank=65.0, Adult.smoking.percentage=15.0, Adult.obesity.percentage=33.0, Excessive.drinking.percentage=20.0, Population.per.sq.mile=45.2, House.per.sq.mile=18.7, Share.of.Tests.with.Positive.COVID.19.Results=0.105847, Number.of.Tests.with.Results.per.1.000.Population=21.6),
#  Row(_c0=597, Active.Physicians.per.100.000.Population..2018..AAMC.=284.4, Total.Active.Patient.Care.Physicians.per.100.000.Population..2018..AAMC.=240.5, Active.Primary.Care.Physicians.per.100.000.Population..2018..AAMC.=99.6, Active.Patient.Care.Primary.Care.Physicians.per.100.000.Population..2018..AAMC.=87.2, Active.General.Surgeons.per.100.000.Population..2018..AAMC.=7.0, Active.Patient.Care.General.Surgeons.per.100.000.Population..2018..AAMC.=5.8, Percentage.of.Active.Physicians.Who.Are.Female..2018..AAMC.=38.7, Percentage.of.Active.Physicians.Who.Are.International.Medical.Graduates..IMGs...2018..AAMC.=30.7, Percentage.of.Active.Physicians.Who.Are.Age.60.or.Older..2018..AAMC.=30.4, MD.and.DO.Student.Enrollment.per.100.000.Population..AY.2018.2019..AAMC.=44.7, Student.Enrollment.at.Public.MD.and.DO.Schools.per.100.000.Population..AY.2018.2019..AAMC.=13.4, Percentage.Change.in.Student.Enrollment.at.MD.and.DO.Schools..2008.2018..AAMC.=2.5, Percentage.of.MD.Students.Matriculating.In.State..AY.2018.2019..AAMC.=62.6, Total.Residents.Fellows.in.ACGME.Programs.per.100.000.Population.as.of.December.31..2018..AAMC.=49.1, Total.Residents.Fellows.in.Primary.Care.ACGME.Programs.per.100.000.Population.as.of.Dec..31..2018..AAMC.=19.8, Percentage.of.Residents.in.ACGME.Programs.Who.Are.IMGs.as.of.December.31..2018..AAMC.=25.9, Ratio.of.Residents.and.Fellows..GME..to.Medical.Students..UME...AY.2017.2018..AAMC.=1.2, Percent.Change.in.Residents.and.Fellows.in.ACGME.Accredited.Programs..2008.2018..AAMC.=7.1, Percentage.of.Physicians.Retained.in.State.from.Undergraduate.Medical.Education..UME...2018..AAMC.=30.9, All.Specialties..AAMC.=2.844342866671898, State.Local.Government.hospital.beds.per.1000.people..2019.=0.1, Non.profit.hospital.beds.per.1000.people..2019.=2.2, For.profit.hospital.beds.per.1000.people..2019.=0.2, Total.hospital.beds.per.1000.people..2019.=2.5, Total.nurse.practitioners..2019.=0.3895274183865651, Total.physician.assistants..2019.=0.19558781515341755, Total.Hospitals..2019.=0.014676934768107983, Total.Primary.Care.Physicians..2019.=1.72614880365691, Surgery.specialists..2019.=0.1611323372832143, Emergency.Medicine.specialists..2019.=0.20767470258180964, Total.Specialist.Physician

# %%
df.show(2,truncate= True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-----------------------------------------------------+------------------------------------------------------------------------+------------------------------------------------------------------+-------------------------------------------------------------------------------+-----------------------------------------------------------+------------------------------------------------------------------------+-----------------------------------------------------------+-------------------------------------------------------------------------------------------+--------------------------------------------------------------------+------------------------------------------------------------------------+------------------------------------------------------------------------------------------+------------------------------------------------------------------------------+---------------------------------------------------------------------+-----------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------+--------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------+----------------------+-----------------------------------------------------------+-----------------------------------------------+-----------------------------------------------+------------------------------------------+--------------------------------+---------------------------------+----------------------+------------------------------------+--------------------------+-------------------------------------+----------------------------------+--------+-------------------+--------------------+---------------------+------------------+------------------------------+-------------------------+------------------------+------------------------+-----------------------------+----------------------+-----------------+---------------------------------------------+-------------------------------------------------+
#  _c0|Active.Physicians.per.100.000.Population..2018..AAMC.|Total.Active.Patient.Care.Physicians.per.100.000.Population..2018..AAMC.|Active.Primary.Care.Physicians.per.100.000.Population..2018..AAMC.|Active.Patient.Care.Primary.Care.Physicians.per.100.000.Population..2018..AAMC.|Active.General.Surgeons.per.100.000.Population..2018..AAMC.|Active.Patient.Care.General.Surgeons.per.100.000.Population..2018..AAMC.|Percentage.of.Active.Physicians.Who.Are.Female..2018..AAMC.|Percentage.of.Active.Physicians.Who.Are.International.Medical.Graduates..IMGs...2018..AAMC.|Percentage.of.Active.Physicians.Who.Are.Age.60.or.Older..2018..AAMC.|MD.and.DO.Student.Enrollment.per.100.000.Population..AY.2018.2019..AAMC.|Student.Enrollment.at.Public.MD.and.DO.Schools.per.100.000.Population..AY.2018.2019..AAMC.|Percentage.Change.in.Student.Enrollment.at.MD.and.DO.Schools..2008.2018..AAMC.|Percentage.of.MD.Students.Matriculating.In.State..AY.2018.2019..AAMC.|Total.Residents.Fellows.in.ACGME.Programs.per.100.000.Population.as.of.December.31..2018..AAMC.|Total.Residents.Fellows.in.Primary.Care.ACGME.Programs.per.100.000.Population.as.of.Dec..31..2018..AAMC.|Percentage.of.Residents.in.ACGME.Programs.Who.Are.IMGs.as.of.December.31..2018..AAMC.|Ratio.of.Residents.and.Fellows..GME..to.Medical.Students..UME...AY.2017.2018..AAMC.|Percent.Change.in.Residents.and.Fellows.in.ACGME.Accredited.Programs..2008.2018..AAMC.|Percentage.of.Physicians.Retained.in.State.from.Undergraduate.Medical.Education..UME...2018..AAMC.|All.Specialties..AAMC.|State.Local.Government.hospital.beds.per.1000.people..2019.|Non.profit.hospital.beds.per.1000.people..2019.|For.profit.hospital.beds.per.1000.people..2019.|Total.hospital.beds.per.1000.people..2019.|Total.nurse.practitioners..2019.|Total.physician.assistants..2019.|Total.Hospitals..2019.|Total.Primary.Care.Physicians..2019.|Surgery.specialists..2019.|Emergency.Medicine.specialists..2019.|Total.Specialist.Physicians..2019.|ICU.Beds|Length.of.Life.rank|Quality.of.Life.rank|Health.Behaviors.rank|Clinical.Care.rank|Social...Economic.Factors.rank|Physical.Environment.rank|Adult.smoking.percentage|Adult.obesity.percentage|Excessive.drinking.percentage|Population.per.sq.mile|House.per.sq.mile|Share.of.Tests.with.Positive.COVID.19.Results|Number.of.Tests.with.Results.per.1.000.Population|
# +----+-----------------------------------------------------+------------------------------------------------------------------------+------------------------------------------------------------------+-------------------------------------------------------------------------------+-----------------------------------------------------------+------------------------------------------------------------------------+-----------------------------------------------------------+-------------------------------------------------------------------------------------------+--------------------------------------------------------------------+------------------------------------------------------------------------+------------------------------------------------------------------------------------------+------------------------------------------------------------------------------+---------------------------------------------------------------------+-----------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------+--------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------+----------------------+-----------------------------------------------------------+-----------------------------------------------+-----------------------------------------------+------------------------------------------+--------------------------------+---------------------------------+----------------------+------------------------------------+--------------------------+-------------------------------------+----------------------------------+--------+-------------------+--------------------+---------------------+------------------+------------------------------+-------------------------+------------------------+------------------------+-----------------------------+----------------------+-----------------+---------------------------------------------+-------------------------------------------------+
#  657|                                                284.4|                                                                   240.5|                                                              99.6|                                                                           87.2|                                                        7.0|                                                                     5.8|                                                       38.7|                                                                                       30.7|                                                                30.4|                                                                    44.7|

# %%
df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: 2169</div>

# %%
len(df.columns), df.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[21]: (46,
#  [&#39;_c0&#39;,
#   &#39;Active.Physicians.per.100.000.Population..2018..AAMC.&#39;,
#   &#39;Total.Active.Patient.Care.Physicians.per.100.000.Population..2018..AAMC.&#39;,
#   &#39;Active.Primary.Care.Physicians.per.100.000.Population..2018..AAMC.&#39;,
#   &#39;Active.Patient.Care.Primary.Care.Physicians.per.100.000.Population..2018..AAMC.&#39;,
#   &#39;Active.General.Surgeons.per.100.000.Population..2018..AAMC.&#39;,
#   &#39;Active.Patient.Care.General.Surgeons.per.100.000.Population..2018..AAMC.&#39;,
#   &#39;Percentage.of.Active.Physicians.Who.Are.Female..2018..AAMC.&#39;,
#   &#39;Percentage.of.Active.Physicians.Who.Are.International.Medical.Graduates..IMGs...2018..AAMC.&#39;,
#   &#39;Percentage.of.Active.Physicians.Who.Are.Age.60.or.Older..2018..AAMC.&#39;,
#   &#39;MD.and.DO.Student.Enrollment.per.100.000.Population..AY.2018.2019..AAMC.&#39;,
#   &#39;Student.Enrollment.at.Public.MD.and.DO.Schools.per.100.000.Population..AY.2018.2019..AAMC.&#39;,
#   &#39;Percentage.Change.in.Student.Enrollment.at.MD.and.DO.Schools..2008.2018..AAMC.&#39;,
#   &#39;Percentage.of.MD.Students.Matriculating.In.State..AY.2018.2019..AAMC.&#39;,
#   &#39;Total.Residents.Fellows.in.ACGME.Programs.per.100.000.Population.as.of.December.31..2018..AAMC.&#39;,
#   &#39;Total.Residents.Fellows.in.Primary.Care.ACGME.Programs.per.100.000.Population.as.of.Dec..31..2018..AAMC.&#39;,
#   &#39;Percentage.of.Residents.in.ACGME.Programs.Who.Are.IMGs.as.of.December.31..2018..AAMC.&#39;,
#   &#39;Ratio.of.Residents.and.Fellows..GME..to.Medical.Students..UME...AY.2017.2018..AAMC.&#39;,
#   &#39;Percent.Change.in.Residents.and.Fellows.in.ACGME.Accredited.Programs..2008.2018..AAMC.&#39;,
#   &#39;Percentage.of.Physicians.Retained.in.State.from.Undergraduate.Medical.Education..UME...2018..AAMC.&#39;,
#   &#39;All.Specialties..AAMC.&#39;,
#   &#39;State.Local.Government.hospital.beds.per.1000.people..2019.&#39;,
#   &#39;Non.profit.hospital.beds.per.1000.people..2019.&#39;,
#   &#39;For.profit.hospital.beds.per.1000.people..2019.&#39;,
#   &#39;Total.hospital.beds.per.1000.people..2019.&#39;,
#   &#39;Total.nurse.practitioners..2019.&#39;,
#   &#39;Total.physician.assistants..2019.&#39;,
#   &#39;Total.Hospitals..2019.&#39;,
#   &#39;Total.Primary.Care.Physicians..2019.&#39;,
#   &#39;Surgery.specialists..2019.&#39;,
#   &#39;Emergency.Medicine.specialists..2019.&#39;,
#   &#39;Total.Specialist.Physicians..2019.&#39;,
#   &#39;ICU.Beds&#39;,
#   &#39;Length.of.Life.rank&#39;,
#   &#39;Quality.of.Life.rank&#39;,
#   &#39;Health.Behaviors.rank&#39;,
#   &#39;Clinical.Care.rank&#39;,
#   &#39;Social...Economic.Factors.rank&#39;,
#   &#39;Physical.Environment.rank&#39;,
#   &#39;Adult.smoking.percentage&#39;,
#   &#39;Adult.obesity.percentage&#39;,
#   &#39;Excessive.drinking.percentage&#39;,
#   &#39;Population.per.sq.mile&#39;,
#   &#39;House.per.sq.mile&#39;,
#   &#39;Share.of.Tests.with.Positive.COVID.19.Results&#39;,
#   &#39;Number.of.Tests.with.Results.per.1.000.Population&#39;])</div>

# %%
df.describe().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+------------------+-----------------------------------------------------+------------------------------------------------------------------------+------------------------------------------------------------------+-------------------------------------------------------------------------------+-----------------------------------------------------------+------------------------------------------------------------------------+-----------------------------------------------------------+-------------------------------------------------------------------------------------------+--------------------------------------------------------------------+------------------------------------------------------------------------+------------------------------------------------------------------------------------------+------------------------------------------------------------------------------+---------------------------------------------------------------------+-----------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------+--------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------+----------------------+-----------------------------------------------------------+-----------------------------------------------+-----------------------------------------------+------------------------------------------+--------------------------------+---------------------------------+----------------------+------------------------------------+--------------------------+-------------------------------------+----------------------------------+-------------------+-------------------+--------------------+---------------------+------------------+------------------------------+-------------------------+------------------------+------------------------+-----------------------------+----------------------+-----------------+---------------------------------------------+-------------------------------------------------+
# summary|               _c0|Active.Physicians.per.100.000.Population..2018..AAMC.|Total.Active.Patient.Care.Physicians.per.100.000.Population..2018..AAMC.|Active.Primary.Care.Physicians.per.100.000.Population..2018..AAMC.|Active.Patient.Care.Primary.Care.Physicians.per.100.000.Population..2018..AAMC.|Active.General.Surgeons.per.100.000.Population..2018..AAMC.|Active.Patient.Care.General.Surgeons.per.100.000.Population..2018..AAMC.|Percentage.of.Active.Physicians.Who.Are.Female..2018..AAMC.|Percentage.of.Active.Physicians.Who.Are.International.Medical.Graduates..IMGs...2018..AAMC.|Percentage.of.Active.Physicians.Who.Are.Age.60.or.Older..2018..AAMC.|MD.and.DO.Student.Enrollment.per.100.000.Population..AY.2018.2019..AAMC.|Student.Enrollment.at.Public.MD.and.DO.Schools.per.100.000.Population..AY.2018.2019..AAMC.|Percentage.Change.in.Student.Enrollment.at.MD.and.DO.Schools..2008.2018..AAMC.|Percentage.of.MD.Students.Matriculating.In.State..AY.2018.2019..AAMC.|Total.Residents.Fellows.in.ACGME.Programs.per.100.000.Population.as.of.December.31..2018..AAMC.|Total.Residents.Fellows.in.Primary.Care.ACGME.Programs.per.100.000.Population.as.of.Dec..31..2018..AAMC.|Percentage.of.Residents.in.ACGME.Programs.Who.Are.IMGs.as.of.December.31..2018..AAMC.|Ratio.of.Residents.and.Fellows..GME..to.Medical.Students..UME...AY.2017.2018..AAMC.|Percent.Change.in.Residents.and.Fellows.in.ACGME.Accredited.Programs..2008.2018..AAMC.|Percentage.of.Physicians.Retained.in.State.from.Undergraduate.Medical.Education..UME...2018..AAMC.|All.Specialties..AAMC.|State.Local.Government.hospital.beds.per.1000.people..2019.|Non.profit.hospital.beds.per.1000.people..2019.|For.profit.hospital.beds.per.1000.people..2019.|Total.hospital.beds.per.1000.people..2019.|Total.nurse.practitioners..2019.|Total.physician.assistants..2019.|Total.Hospitals..2019.|Total.Primary.Care.Physicians..2019.|Surgery.specialists..2019.|Emergency.Medicine.specialists..2019.|Total.Specialist.Physicians..2019.|           ICU.Beds|Length.of.Life.rank|Quality.of.Life.rank|Health.Behaviors.rank|Clinical.Care.rank|Social...Economic.Factors.rank|Physical.Environment.rank|Adult.smoking.percentage|Adult.obesity.percentage|Excessive.drinking.percentage|Population.per.sq.mile|House.per.sq.mile|Share.of.Tests.with.Positive.COVID.19.Results|Number.of.Tests.with.Results.per.1.000.Population|
# +-------+------------------+-----------------------------------------------------+------------------------------------------------------------------------+------------------------------------------------------------------+-------------------------------------------------------------------------------+-----------------------------------------------------------+------------------------------------------------------------------------+-----------------------------------------------------------+-------------------------------------------------------------------------------------------+--------------------------------------------------------------------+------------------------------------------------------------------------+------------------------------------------------------------------------------------------+------------------------------------------------------------------------------+---------------------------------------------------------------------+-----------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------+--------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------+----------------------+-----------------------------------------------------------+-----------------------------------------------+-----------------------------------------------+------------------------------------------+--------------------------------+---------------------------------+----------------------+------------------------------------+--------------------------+-------------------------------------+----------------------------------+-------------------+-------------------+--------------------+---------------------+------------------+------------------------------+-------------------------+------------------------+------------------------+-----------------------------+----------------------+-----------------+---------------------------------------------+-------------------------------------------------+
#   count|              2169|                                                 2169|                                                                    2169|                                                              2169|                                                                           2169|                                                       2169|                                                                    2169|                                                       2169|                                                                                       2169|

# %%
df.describe('cases').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-----------------+
# summary|            cases|
# +-------+-----------------+
#   count|             3576|
#    mean| 9531.66023489933|
#  stddev|30365.27754584857|
#     min|                1|
#     max|           342267|
# +-------+-----------------+
#
# </div>

# %%
df.select('fips','cases').show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-----+
# fips|cases|
# +----+-----+
#   53|    1|
#   53|    1|
#   53|    1|
#   17|    1|
#   53|    1|
# +----+-----+
# only showing top 5 rows
#
# </div>

# %%
df.select('fips','cases').distinct().count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[11]: 3187</div>

# %%
#df.crosstab('state', 'cases').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#df.crosstab('state', 'cases').dropDuplicates().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.dropna().count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[14]: 3576</div>

# %%
df.groupby('state').agg({'cases': 'mean'}).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------+------------------+
#         state|        avg(cases)|
# +-------------+------------------+
#          Utah|1942.4545454545455|
#        Hawaii|346.85074626865674|
#     Minnesota| 2467.791044776119|
#          Ohio|       8406.296875|
#        Oregon|1178.9054054054054|
#      Arkansas| 1572.532258064516|
#         Texas|10063.977777777778|
#  North Dakota|486.19354838709677|
#  Pennsylvania|21706.194029850747|
#   Connecticut|12695.923076923076|
#      Nebraska|1436.2941176470588|
#       Vermont|499.92424242424244|
#        Nevada| 2471.294117647059|
#    Washington| 4966.732142857143|
#      Illinois|14557.853211009175|
#      Oklahoma|1751.3283582089553|
#      Delaware| 2133.983870967742|
#        Alaska|215.78688524590163|
#    New Mexico|1594.1935483870968|
# West Virginia| 645.3928571428571|
# +-------------+------------------+
# only showing top 20 rows
#
# </div>

# %%
df.groupby('cases').count().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+-----+
# cases|count|
# +-----+-----+
#  6620|    1|
#  1580|    2|
#   463|    1|
# 25591|    1|
#  1342|    1|
#  3175|    1|
# 15846|    1|
#  2387|    1|
#   392|    2|
#  4161|    1|
#   623|    2|
#  1721|    2|
#   540|    1|
#  1507|    1|
#  4929|    1|
#  1025|    1|
# 23607|    1|
# 26767|    1|
# 42348|    1|
#   897|    1|
# +-----+-----+
# only showing top 20 rows
#
# </div>

# %%
#df.select('date').map(lambda x:(x,1)).take(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.orderBy(df.cases.desc()).show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+--------+----+------+------+----------------------+--------------------+---------------+-------------------------------+
#      date|   state|fips| cases|deaths|Date_Start_of_Lockdown|Date_End_of_Lockdown|Lockdown_Length|Noramliztion factor (per 1,000)|
# +---------+--------+----+------+------+----------------------+--------------------+---------------+-------------------------------+
# 5/11/2020|New York|  36|342267| 27003|                22-Mar|              15-May|             54|                        5.14E-5|
# 5/10/2020|New York|  36|340657| 26798|                22-Mar|              15-May|             54|                        5.14E-5|
#  5/9/2020|New York|  36|338519| 26584|                22-Mar|              15-May|             54|                        5.14E-5|
#  5/8/2020|New York|  36|335804| 26358|                22-Mar|              15-May|             54|                        5.14E-5|
#  5/7/2020|New York|  36|332931| 26206|                22-Mar|              15-May|             54|                        5.14E-5|
# +---------+--------+----+------+------+----------------------+--------------------+---------------+-------------------------------+
# only showing top 5 rows
#
# </div>

# %%
# %fs ls
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/</td><td>FileStore/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/</td><td>databricks-datasets/</td><td>0</td></tr><tr><td>dbfs:/databricks-results/</td><td>databricks-results/</td><td>0</td></tr><tr><td>dbfs:/tmp/</td><td>tmp/</td><td>0</td></tr></tbody></table></div>

# %%
# %fs ls dbfs:/databricks-datasets
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/databricks-datasets/</td><td>databricks-datasets/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/COVID/</td><td>COVID/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/README.md</td><td>README.md</td><td>976</td></tr><tr><td>dbfs:/databricks-datasets/Rdatasets/</td><td>Rdatasets/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/SPARK_README.md</td><td>SPARK_README.md</td><td>3359</td></tr><tr><td>dbfs:/databricks-datasets/adult/</td><td>adult/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/airlines/</td><td>airlines/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/amazon/</td><td>amazon/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/asa/</td><td>asa/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/atlas_higgs/</td><td>atlas_higgs/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/bikeSharing/</td><td>bikeSharing/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/cctvVideos/</td><td>cctvVideos/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/credit-card-fraud/</td><td>credit-card-fraud/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/cs100/</td><td>cs100/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/cs110x/</td><td>cs110x/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/cs190/</td><td>cs190/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/data.gov/</td><td>data.gov/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/definitive-guide/</td><td>definitive-guide/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/flights/</td><td>flights/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/flower_photos/</td><td>flower_photos/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/flowers/</td><td>flowers/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/genomics/</td><td>genomics/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/hail/</td><td>hail/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/iot/</td><td>iot/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/iot-stream/</td><td>iot-stream/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/learning-spark/</td><td>learning-spark/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/learning-spark-v2/</td><td>learning-spark-v2/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/lending-club-loan-stats/</td><td>lending-club-loan-stats/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/med-images/</td><td>med-images/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/mnist-digits/</td><td>mnist-digits/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/news20.binary/</td><td>news20.binary/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/nyctaxi/</td><td>nyctaxi/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/online_retail/</td><td>online_retail/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/overlap-join/</td><td>overlap-join/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/power-plant/</td><td>power-plant/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/rwe/</td><td>rwe/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/sai-summit-2019-sf/</td><td>sai-summit-2019-sf/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/sample_logs/</td><td>sample_logs/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/samples/</td><td>samples/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/sfo_customer_survey/</td><td>sfo_customer_survey/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/sms_spam_collection/</td><td>sms_spam_collection/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/songs/</td><td>songs/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/structured-streaming/</td><td>structured-streaming/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/timeseries/</td><td>timeseries/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/tpch/</td><td>tpch/</td ...
